# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('spotify.csv')

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# ...

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
df.head(5)
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %%
#-Q1- Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
duplicates_in_columns = df.apply(lambda col: col.duplicated().any())

# %%
duplicates_in_columns
# Out:
# Artist           True
# Track Name       True
# Popularity       True
# Duration (ms)    True
# Track ID         True
# dtype: bool

# %%
duplicates_in_product_name = df[df['Track Name'].duplicated()]
duplicates_in_product_name
# Out:
#               Artist                                         Track Name  \
# 19        Noah Kahan                      Dial Drunk (with Post Malone)
# 39      Travis Scott                             MELTDOWN (feat. Drake)
# 52      Travis Scott                   TELEKINESIS (feat. SZA & Future)
# 72         21 Savage                                            née-nah
# 73             Drake                      Jimmy Cooks (feat. 21 Savage)
# 76             Drake                                          Rich Flex
# 131            Drake               First Person Shooter (feat. J. Cole)
# 170     Metro Boomin            Trance (with Travis Scott & Young Thug)
# 182   D-Block Europe                                           Overseas
# 210      Post Malone      Sunflower - Spider-Man: Into the Spider-Verse
# 212     Metro Boomin  Annihilate (Spider-Man: Across the Spider-Vers...
# 222          Cardi B                    WAP (feat. Megan Thee Stallion)
# ...

# %%
df.drop_duplicates() # droped duplicate values
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 433  French Montana                                       Stand United
# 434    Jason Derulo                     Tip Toe (feat. French Montana)
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
#-Q2-What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram

track_popularity = df.groupby('Track Name')['Popularity'].mean().reset_index()
track_popularity
# Out:
#                                   Track Name  Popularity
# 0                                     20 Min        84.0
# 1    3 Headed Goat (feat. Lil Baby & Polo G)        75.0
# 2                     3D (feat. Jack Harlow)        84.0
# 3                                       4:44        74.0
# 4                              6 Foot 7 Foot        74.0
# ..                                       ...         ...
# 407                              pop ur shit        79.0
# 408                                 prove it        82.0
# 409              pushin P (feat. Young Thug)        75.0
# 410                                   redrum        96.0
# 411               rockstar (feat. 21 Savage)        85.0
#
# [412 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))

# Loop over unique track names
for track in df['Track Name'].unique():
    sns.histplot(
        df[df['Track Name'] == track]['Popularity'],
        kde=True,
        label=track,
        alpha=0.5
    )

# Add plot details
plt.title('Distribution of Popularity by Track')
plt.xlabel('Popularity Score')
plt.ylabel('Frequency')
plt.legend(title='Track Name')

# Show plot
plt.show()

# %%
#-Q3- Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
correlation = df['Popularity'].corr(df['Duration (ms)'])
print(f"Correlation between Popularity and Duration: {correlation:.2f}")
# Out:
# Correlation between Popularity and Duration: 0.04

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Duration (ms)', y='Popularity', s=100, color='blue')
# Out:
# <Axes: xlabel='Duration (ms)', ylabel='Popularity'>

# %%
#-Q4-Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df['Artist'].value_counts()
# Out:
# Artist
# Drake             20
# Travis Scott      12
# 21 Savage         11
# ¥$                11
# Lil Nas X         11
#                   ..
# Arizona Zervas     1
# Fivio Foreign      1
# Pressa             1
# David Guetta       1
# Diddy              1
# Name: count, Length: 115, dtype: int64

# %%
artist_track_count = df['Artist'].value_counts()
print("Number of Tracks for Each Artist:")
print(artist_track_count)

# Create a countplot for the number of tracks per artist
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='Artist', order=artist_track_count.index, palette='viridis')

# Add plot details
plt.title('Number of Tracks by Each Artist')
plt.xlabel('Artist')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.show()
# Out:
# Number of Tracks for Each Artist:
# Artist
# Drake             20
# Travis Scott      12
# 21 Savage         11
# ¥$                11
# Lil Nas X         11
#                   ..
# Arizona Zervas     1
# Fivio Foreign      1
# Pressa             1
# David Guetta       1
# Diddy              1
# Name: count, Length: 115, dtype: int64
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_4868\763872224.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Artist', order=artist_track_count.index, palette='viridis')

# %%
#-Q5-What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
least_popular_tracks = df.nsmallest(5, 'Popularity')[['Track Name', 'Artist', 'Popularity']]
least_popular_tracks
# Out:
#                         Track Name          Artist  Popularity
# 207  Attachments (feat. Coi Leray)          Pressa          29
# 231                     Intentions   Justin Bieber          35
# 413                Splash Brothers  French Montana          44
# 435                Splash Brothers  French Montana          44
# 225                  On Me - Remix        Lil Baby          47

# %%
#-Q6- Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist
#highest_popular_tracks = df.nlargest('Popularity')[['Track Name', 'Artist', 'Popularity']]
highest_popular_tracks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 #-Q6- Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist
# ----> 2 highest_popular_tracks = df.nlargest('Popularity')[['Track Name', 'Artist', 'Popularity']]
#       3 highest_popular_tracks
#
# TypeError: DataFrame.nlargest() missing 1 required positional argument: 'columns'

# %%
artist_popularity = df.groupby('Artist')['Popularity'].sum()
artist_popularity
# Out:
# Artist
# *NSYNC                     67
# 2 Chainz                   72
# 21 Savage                 926
# A Boogie Wit da Hoodie     80
# A$AP Ferg                  69
#                          ...
# Young Nudy                 67
# Young Thug                295
# benny blanco               72
# cassö                      92
# ¥$                        947
# Name: Popularity, Length: 115, dtype: int64

# %%
top_5_artists = artist_popularity.nlargest(5).index
top_5_artists
# Out:
# Index(['Drake', 'Travis Scott', '¥$', '21 Savage', 'Eminem'], dtype='object', name='Artist')

# %%
top_5_artists_df = df[df['Artist'].isin(top_5_artists)]
top_5_artists_df
# Out:
#         Artist                                        Track Name  Popularity  \
# 0        Drake           Rich Baby Daddy (feat. Sexyy Red & SZA)          92
# 1        Drake                                         One Dance          91
# 2        Drake                                IDGAF (feat. Yeat)          90
# 3        Drake              First Person Shooter (feat. J. Cole)          88
# 4        Drake                     Jimmy Cooks (feat. 21 Savage)          88
# ..         ...                                               ...         ...
# 294      Drake                  Wants and Needs (feat. Lil Baby)          81
# 298      Drake                  Girls Want Girls (with Lil Baby)          78
# 410      Drake          Money In The Grave (Drake ft. Rick Ross)          79
# 417      Drake  You Only Live Twice (with Lil Wayne & Rick Ross)          65
# 427  21 Savage            Ghostface Killers (feat. Travis Scott)          73
#
#      Duration (ms)                Track ID
# ...

# %%
average_popularity = top_5_artists_df.groupby('Artist')['Popularity'].mean()
average_popularity
# Out:
# Artist
# 21 Savage       84.181818
# Drake           83.500000
# Eminem          83.636364
# Travis Scott    87.000000
# ¥$              86.090909
# Name: Popularity, dtype: float64

# %%
#-Q7_For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist
artist_popularity = df.groupby('Artist')['Popularity'].sum()
top_5_artists = artist_popularity.nlargest(5).index
top_5_artists_df = df[df['Artist'].isin(top_5_artists)]['Track Name']	

top_5_artists_df
# Out:
# 0               Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1                                             One Dance
# 2                                    IDGAF (feat. Yeat)
# 3                  First Person Shooter (feat. J. Cole)
# 4                         Jimmy Cooks (feat. 21 Savage)
#                              ...
# 294                    Wants and Needs (feat. Lil Baby)
# 298                    Girls Want Girls (with Lil Baby)
# 410            Money In The Grave (Drake ft. Rick Ross)
# 417    You Only Live Twice (with Lil Wayne & Rick Ross)
# 427              Ghostface Killers (feat. Travis Scott)
# Name: Track Name, Length: 65, dtype: object

# %%
#-Q8-Visualize relationships between multiple numerical variables simultaneously using a pair plot
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
num_col = df.select_dtypes(exclude = 'object')

# %%
num_col
# Out:
#      Popularity  Duration (ms)
# 0            92         319191
# 1            91         173986
# 2            90         260111
# 3            88         247444
# 4            88         218364
# ..          ...            ...
# 435          44         221863
# 436          64         191900
# 437          69         283693
# 438          65         220408
# 439          68         267720
#
# [440 rows x 2 columns]

# %%
sns.pairplot(num_col[['Popularity', 'Duration (ms)']])


plt.show()

# %%
#-Q9- Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Artist', y='Duration (ms)', palette='Set2')

# Add titles and labels
plt.title('Track Duration Across Different Artists', fontsize=16)
plt.xlabel('Artist', fontsize=12)
plt.ylabel('Duration (ms)', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_4868\2147914772.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Artist', y='Duration (ms)', palette='Set2')

# %%
# Create a violin plot for the duration of tracks across different artists
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Artist', y='Duration (ms)', palette='Set2')

# Add titles and labels
plt.title('Track Duration Distribution Across Different Artists', fontsize=16)
plt.xlabel('Artist', fontsize=12)
plt.ylabel('Duration (ms)', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_4868\857392320.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Artist', y='Duration (ms)', palette='Set2')
